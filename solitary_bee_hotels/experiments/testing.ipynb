# %%
import os
os.chdir("/Users/edwardamoah/Documents/GitHub/BeeVision")

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 4.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.9/246.9 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 20.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 20.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.6 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
#model = YOLO('/Users/edwardamoah/Documents/GitHub/BeeVision/runs/detect/train12/weights/best.pt')
model = 'yolov8n.pt'

# Define path to video file
source = '/Users/edwardamoah/Documents/GitHub/BeeVision/datasets/images/motion_frame_1.jpg'

# %%
# run model
results = model(source)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb Cell 4 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # run model
# ----> <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> results = model(source)
#
# TypeError: 'str' object is not callable

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'Complete_Hole', 1: 'Hole', 2: 'flying_bee'}
# orig_img: array([[[227, 226, 165],
#         [225, 224, 163],
#         [224, 223, 162],
#         ...,
#         [142, 168, 120],
#         [145, 169, 121],
#         [146, 170, 122]],
#
#        [[226, 225, 164],
#         [225, 224, 163],
#         [224, 223, 162],
#         ...,
#         [143, 169, 121],
#         [145, 169, 121],
#         [146, 170, 122]],
#
#        [[227, 226, 165],
#         [227, 226, 165],
#         [227, 226, 165],
#         ...,
#         [142, 168, 122],
#         [143, 169, 123],
#         [143, 169, 123]],
#
#        ...,
#
#        [[ 54,  30,  18],
#         [ 54,  30,  18],
#         [ 54,  30,  18],
#         ...,
#         [ 74,  55,  34],
#         [ 74,  55,  34],
#         [ 74,  55,  34]],
#
#        [[ 54,  30,  18],
# ...

# %%
print(results[0].tojson())
# Out:
# []

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model

model = YOLO('/Users/edwardamoah/Documents/GitHub/BeeVision/runs/detect/train12/weights/best.pt')

# Run batched inference on a list of images
results = model(['/Users/edwardamoah/Documents/GitHub/BeeVision/datasets/images/motion_frame_1.jpg'])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
print(probs)
# Out:
# None

# %%
model_path = '/Users/edwardamoah/Documents/GitHub/BeeVision/runs/detect/train12/weights/best.pt'

# %%
source = '/Users/edwardamoah/Documents/GitHub/BeeVision/datasets/images/motion_frame_1.jpg'

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
#model = YOLO(model_path)
model = YOLO('yolov8n.pt')

# Define path to the image file
#source = 'path/to/image.jpg'

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 28.4MB/s]
# image 1/1 /Users/edwardamoah/Documents/GitHub/BeeVision/datasets/images/motion_frame_1.jpg: 384x640 1 clock, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
#results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Complete_Hole', 1: 'Hole', 2: 'flying_bee'}
#  orig_img: array([[[227, 226, 165],
#          [225, 224, 163],
#          [224, 223, 162],
#          ...,
#          [142, 168, 120],
#          [145, 169, 121],
#          [146, 170, 122]],
#
#         [[226, 225, 164],
#          [225, 224, 163],
#          [224, 223, 162],
#          ...,
#          [143, 169, 121],
#          [145, 169, 121],
#          [146, 170, 122]],
#
#         [[227, 226, 165],
#          [227, 226, 165],
#          [227, 226, 165],
#          ...,
#          [142, 168, 122],
#          [143, 169, 123],
#          [143, 169, 123]],
#
#         ...,
#
#         [[ 54,  30,  18],
#          [ 54,  30,  18],
#          [ 54,  30,  18],
#          ...,
#          [ 74,  55,  34],
#          [ 74,  55,  34],
#          [ 74,  55,  34]],
#
# ...

# %%
model.predict(source, conf=0.5, imgsz=640, show=True, show_labels=True)
# Out:
# image 1/1 /Users/edwardamoah/Documents/GitHub/BeeVision/datasets/images/motion_frame_1.jpg: 384x640 (no detections), 55.5ms
# Speed: 1.6ms preprocess, 55.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# !pip install -U ultralyticsplus==0.0.14
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 5.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/32.6 MB 11.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 17.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('ultralyticsplus/yolov8s')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
image = 'https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg'

# perform inference
results = model.predict(image)

# observe results
print(results[0].boxes)
render = render_result(model=model, image=image, result=results[0])
render.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb Cell 15 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> from ultralyticsplus import YOLO, render_result
#       <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> # load model
#       <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> model = YOLO('ultralyticsplus/yolov8s')
#
# File ~/opt/anaconda3/envs/geoanalysis_env/lib/python3.10/site-packages/ultralyticsplus/__init__.py:1, in <module>
# ----> 1 from .hf_utils import download_from_hub, push_to_hfhub
# ...

# %%
# !pip install Shapely-1.6.4.post1-cp37-cp37m-win_amd64.whl
# Out:
# WARNING: Requirement 'Shapely-1.6.4.post1-cp37-cp37m-win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: Shapely-1.6.4.post1-cp37-cp37m-win_amd64.whl is not a supported wheel on this platform.

# %%
from ultralytics import YOLO
from PIL import Image

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Run inference on an image
results = model('https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg')  # results list

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# Found https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg locally at zidane.jpg
# Ultralytics YOLOv8.0.8 🚀 Python-3.10.6 torch-2.1.1 CPU
# Fusing layers...
# YOLOv8n summary: 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb Cell 17 line <cell line: 11>()
#      <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a> # Show the results
#      <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a> for r in results:
# ...

# %%
# View results
for r in results:
    print(r.boxes["id"])  # print the Boxes object containing the detection bounding boxes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb Cell 18 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # View results
#       <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for r in results:
# ----> <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     print(r.boxes["id"])
#
# File ~/opt/anaconda3/envs/geoanalysis_env/lib/python3.10/site-packages/ultralytics/yolo/engine/results.py:200, in Boxes.__getitem__(self, idx)
#     199 def __getitem__(self, idx):
# --> 200     boxes = self.boxes[idx]
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = 'https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg'
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics YOLOv8.0.8 🚀 Python-3.10.6 torch-2.1.1 CPU
# Fusing layers...
# YOLOv8n summary: 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb Cell 19 line <cell line: 12>()
#      <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X24sZmlsZQ%3D%3D?line=17'>18</a> results = model(frame)
#      <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X24sZmlsZQ%3D%3D?line=19'>20</a> # Visualize the results on the frame
# ---> <a href='vscode-notebook-cell:/Users/edwardamoah/Documents/GitHub/BeeVision/training/testing.ipynb#X24sZmlsZQ%3D%3D?line=20'>21</a> annotated_frame = results[0].plot()
# ...

# %%
############## ID Generation #####################

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('/Users/edwardamoah/Documents/GitHub/BeeVision/runs/detect/train11/weights/best.pt')


# Define the path to the image file
image_path = '/Users/edwardamoah/Documents/GitHub/BeeVision/datasets/images/motion_frame_0.jpg'

# Load the image
image = cv2.imread(image_path)

# Run YOLOv8 inference on the image
results = model(image)

# Visualize the results on the frame
annotated_frame = results[0].plot()
# Out:
# 0: 384x640 4 Complete_Holes, 28 Holes, 45.8ms
# Speed: 2.3ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
import matplotlib.pyplot as plt

plt.imshow(annotated_frame)
plt.axis('off')
plt.show()

# %%
cords = results[0].boxes.xyxy.tolist()

# %%
#results[0].boxes.conf

# %%
labels = results[0].boxes.cls.tolist()

# %%
import pandas as pd
df = pd.DataFrame({
    "coordinates" : cords,
    "labels" : labels
})

# %%
#sorted_coordinates = sorted(df.coordinates, key=lambda c: (c[0], c[1]))

#sorted_coordinates = sorted(df.coordinates, key=lambda c: (c[0], c[1]))

sorted_coordinates = sorted(df.coordinates, key=lambda c: (c[0], c[1]))

# %%
def getID(cords):
    return sorted_coordinates.index(cords)

# %%
df['id'] = df['coordinates'].apply(getID)

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
def drawBox(image, cords, ID):
    x1, y1, x2, y2 = cords
    cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(image, str(ID), (int(x1), int(y1) - 5), font, 0.5, (0, 255, 0), 2)
    return image

# %%
img1 = image.copy()
for cord in sorted_coordinates:
    ID = getID(cord)
    img1 = drawBox(img1, cord, ID)

# %%
# Display the image
plt.figure(figsize=(10, 8))
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
#################### tracking experiments ###########

# %%
from collections import defaultdict

import cv2
import numpy as np

from ultralytics import YOLO

# Load the YOLOv8 model
#model = YOLO('yolov8n.pt')
model = YOLO('/Users/edwardamoah/Documents/GitHub/BeeVision/solitary_bee_hotels/runs/detect/train14/weights/best.pt')

# Open the video file
video_path = "/Users/edwardamoah/Documents/GitHub/BeeVision/solitary_bee_hotels/datasets/videos/2023-05-10_17_46_37.mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Get the boxes and track IDs
        boxes = results[0].boxes.xywh.cpu()
        try:
            track_ids = results[0].boxes.id.int().cpu().tolist()
        except:
            track_ids = np.arange(len(boxes))

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))  # x, y center point
            if len(track) > 30:  # retain 90 tracks for 90 frames
                track.pop(0)

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.3ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('/Users/edwardamoah/Documents/GitHub/BeeVision/solitary_bee_hotels/runs/detect/train14/weights/best.pt')  # bee detection model

source = '/Users/edwardamoah/Documents/GitHub/BeeVision/solitary_bee_hotels/datasets/videos/2023-05-10_17_46_37.mp4'

#cap = cv2.VideoCapture(source)

results = model.track(source=source, show=True, tracker='bytetrack.yaml', persist=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/6060) /Users/edwardamoah/Documents/GitHub/BeeVision/solitary_bee_hotels/datasets/videos/2023-05-10_17_46_37.mp4: 384x640 (no detections), 52.3ms
# video 1/1 (2/6060) /Users/edwardamoah/Documents/GitHub/BeeVision/solitary_bee_hotels/datasets/videos/2023-05-10_17_46_37.mp4: 384x640 (no detections), 49.5ms
# ...
